# %%
import pandas as pd

data = pd.read_csv('Salary_Data.csv')

#mengecek apakah ada data yg null atau kosong
#data.info()

import numpy as np

# Memisahkan Atribut dan Label
x = data['YearsExperience']
y = data['Salary']

# Mengubah bentuk Atribut
x = x[:, np.newaxis]

from sklearn.svm import SVR

# membangun model dengan parameter C, gmma dan kernel
model = SVR(C=1000, gamma=0.05, kernel='rbf')

#melatih model dengan fungsi fit
model.fit(x,y)

# memvisualisasikan model
import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.plot(x, model.predict(x))
# Out:
# <ipython-input-5-98c9049a9701>:15: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
